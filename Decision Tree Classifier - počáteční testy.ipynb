# %%
# %pylab --no-import-all notebook
import Classification as CL
#import numpy as np
#import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier as DTC
import pandas as pd
from bunch import Bunch
import datasets as d
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = d.load_dataset(name="first_dataset")

type(data)
# Out:
# bunch.Bunch

# %%
Tree = DTC(criterion="entropy")

res = CL.validuj(model = Tree,
                 train_data = data[:-1],
                 test_data = [data[-1]],
                 delka_okna=[4,7,12,12],
                 parametry=[1,1,1,1,1],
                 HMMmodified=False,
                 unsupervised=False)

# %%
print(type(res[0]))
res[0].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Kombinace rysů     délka úseku  Accuracy  Chyby  F míra stavu 0  \
# 0  (1, 1, 1, 1, 1)  [4, 7, 12, 12]  0.876333    371        0.931333
# 1                0               0  0.000000      0        0.000000
#
#    F míra stavu 1  F míra stavu 2  F míra průměrná  Precision stavu 0  \
# 0        0.805524        0.798799         0.845218           0.971119
# 1        0.000000        0.000000         0.000000           0.000000
#
#    Precision stavu 1  Precision stavu 2  Recall stavu 0  Recall stavu 1  \
# 0           0.786517           0.744681        0.894678        0.825472
# 1           0.000000           0.000000        0.000000        0.000000
#
#    Recall stavu 2
# 0        0.861399
# 1        0.000000

# %%
plt.plot(data[-1][0], data[-1][1])
plt.scatter(data[-1][0], data[-1][1], c=res[1], cmap=plt.cm.plasma)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
res[3]/len(data[-1][2])
# Out:
# 2.0820299784342448e-05

# %%
d.shape(data)
# Out:
# (10, 3, [3596, 3188, 3387, 3319, 3667, 3646, 3140, 3119, 2754, 3000], 32816)

# %%
Tree_gini = DTC(criterion="gini")

test_2 = CL.validuj(model = Tree_gini,
                 train_data = data[:-1],
                 test_data = [data[-1]],
                 delka_okna=[4,7,12,12],
                 parametry=[1,1,1,1,1],
                 HMMmodified=False,
                 unsupervised=False)

# %%
test_2[0].head(1)
# Out:
#     Kombinace rysů     délka úseku  Accuracy  Chyby  F míra stavu 0  \
# 0  (1, 1, 1, 1, 1)  [4, 7, 12, 12]  0.864667    406        0.934063
#
#    F míra stavu 1  F míra stavu 2  F míra průměrná  Precision stavu 0  \
# 0        0.760563        0.773731         0.822786           0.971839
#
#    Precision stavu 1  Precision stavu 2  Recall stavu 0  Recall stavu 1  \
# 0           0.757009           0.717608        0.899113        0.764151
#
#    Recall stavu 2
# 0        0.839378

# %%
res[0].head(1)
# Out:
#     Kombinace rysů     délka úseku  Accuracy  Chyby  F míra stavu 0  \
# 0  (1, 1, 1, 1, 1)  [4, 7, 12, 12]  0.876333    371        0.931333
#
#    F míra stavu 1  F míra stavu 2  F míra průměrná  Precision stavu 0  \
# 0        0.805524        0.798799         0.845218           0.971119
#
#    Precision stavu 1  Precision stavu 2  Recall stavu 0  Recall stavu 1  \
# 0           0.786517           0.744681        0.894678        0.825472
#
#    Recall stavu 2
# 0        0.861399

# %% [markdown]
# ## Předběžně je entropie lepší než gini
