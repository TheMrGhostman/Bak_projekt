# %%
# %pylab --no-import-all notebook
import Classification as CL
#import numpy as np
#import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier as DTC
import pandas as pd
from bunch import Bunch
import datasets as d
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os 
valid_path = os.getcwd() + "/Validační tabulky/"

# %%
data = d.load_dataset(name="first_dataset")

# %%
train, test = d.PrepareCrossFold(data.data)

# %%
train1 = data.data[:-1]
test1 = data.data[-1]

# %%
CLF = DTC(criterion="entropy")

# %%
d.shape(train[0])
# Out:
# (9, 3, [3596, 3188, 3387, 3319, 3667, 3646, 3140, 3119, 2754], 29816)

# %%
d.shape(train1)
# Out:
# (9, 3, [3596, 3188, 3387, 3319, 3667, 3646, 3140, 3119, 2754], 29816)

# %%
d.shape(test)
# Out:
# (3, 3000, [], 0)

# %%
tab = CL.validace_hromadna(CLF, train, [test], delka_okna=[[4, 6], [8, 10], [12, 14, 16], range(5,17)],\
                           pocet_stavu=3, unsupervised = False, HMMmodified=False)
# Out:
# [                                                                        ] N/A%
# [[4, 6], [8, 10], [12, 14, 16], range(5, 17)]
# [[4, 6], [8, 10], [12, 14, 16], range(5, 17)]
# [########################################################################] 100%
# 2062.216917037964

# %%
# ?CL.validace_hromadna

# %%
#tab.to_csv(valid_path + 'Real_data_DTC_Hm.csv',index=False)

# %%
tab.sort_values(['Accuracy'], ascending=False).head(5)
# Out:
#        Kombinace rysů     délky úseku  Accuracy  Chyby  F míra stavu 0  \
# 3707  (1, 1, 1, 0, 1)  (6, 8, 12, 16)  0.907667   -277        0.943450
# 3779  (1, 1, 1, 0, 1)  (6, 0, 12, 16)  0.904667   -286        0.941847
# 3791  (1, 1, 1, 0, 1)  (6, 0, 14, 16)  0.903667   -289        0.941612
# 3719  (1, 1, 1, 0, 1)  (6, 8, 14, 16)  0.903333   -290        0.943353
# 3611  (1, 1, 1, 0, 1)  (4, 8, 14, 16)  0.902333   -293        0.940806
#
#       F míra stavu 1  F míra stavu 2  F míra průměrná  Precision stavu 0  \
# 3707        0.887446        0.838793         0.889896           0.967930
# 3779        0.880952        0.835459         0.886086           0.969484
# 3791        0.879050        0.833013         0.884558           0.968366
# 3719        0.876772        0.829299         0.883142           0.969573
# 3611        0.878689        0.831234         0.883576           0.971648
#
#       Precision stavu 1  Precision stavu 2  Recall stavu 0  Recall stavu 1  \
# ...

# %%
tab = np.empty([10]).tolist()

# %%
tab[1] = CL.validace_hromadna(CLF, train[1], test[1], delka_okna=[[4, 6], [8, 10], [12, 14, 16], range(5,17)],\
                           pocet_stavu=3, unsupervised = False, HMMmodified=False)
# Out:
# [########################################################################] 100%
# 2071.159056186676

# %%
tab[1].to_csv(valid_path + 'Real_data_DTC_Hm_1.csv',index=False)

# %%
tab[1].sort_values(['Accuracy'], ascending=False).head(5)
# Out:
#        Kombinace rysů      délky úseku  Accuracy  Chyby  F míra stavu 0  \
# 3973  (1, 1, 1, 1, 1)   (4, 8, 16, 15)  0.820261   2754        0.824752
# 3303  (1, 1, 0, 1, 1)  (4, 10, 16, 11)  0.818446   2754        0.831603
# 3378  (1, 1, 0, 1, 1)   (6, 8, 16, 14)  0.818083   2754        0.831440
# 3887  (1, 1, 1, 0, 1)   (0, 0, 12, 16)  0.817720   2754        0.833713
# 4043  (1, 1, 1, 1, 1)   (4, 0, 16, 13)  0.817720   2754        0.821733
#
#       F míra stavu 1  F míra stavu 2  F míra průměrná  Precision stavu 0  \
# 3973        0.839304        0.807941         0.823999           0.736290
# 3303        0.822938        0.803828         0.819456           0.742143
# 3378        0.814141        0.807078         0.817553           0.745721
# 3887        0.809082        0.806314         0.816370           0.749386
# 4043        0.839836        0.804508         0.822026           0.730247
#
#       Precision stavu 1  Precision stavu 2  Recall stavu 0  Recall stavu 1  \
# ...

# %%
tab[2] = CL.validace_hromadna(CLF, train[2], test[2], delka_okna=[[4, 6], [8, 10], [12, 14, 16], range(5,17)],\
                           pocet_stavu=3, unsupervised = False, HMMmodified=False)
# Out:
# [########################################################################] 100%
# 2104.1031959056854

# %%
tab[2].to_csv(valid_path + 'Real_data_DTC_Hm_2.csv',index=False)

# %%
tab[2].sort_values(['Accuracy'], ascending=False).head(5)
# Out:
#        Kombinace rysů      délky úseku  Accuracy  Chyby  F míra stavu 0  \
# 3647  (1, 1, 1, 0, 1)  (4, 10, 14, 16)  0.915357   3119        0.946670
# 3837  (1, 1, 1, 0, 1)   (0, 8, 16, 14)  0.913754   3119        0.948481
# 4111  (1, 1, 1, 1, 1)   (6, 10, 16, 9)  0.912151   3119        0.946067
# 3428  (1, 1, 0, 1, 1)   (6, 0, 12, 16)  0.912151   3119        0.945675
# 4107  (1, 1, 1, 1, 1)   (6, 10, 16, 5)  0.912151   3119        0.943962
#
#       F míra stavu 1  F míra stavu 2  F míra průměrná  Precision stavu 0  \
# 3647        0.870824        0.865691         0.894395           0.952483
# 3837        0.861298        0.859525         0.889768           0.950238
# 4111        0.860386        0.858612         0.888355           0.943832
# 3428        0.857143        0.861914         0.888244           0.945675
# 4107        0.871332        0.857511         0.890935           0.941732
#
#       Precision stavu 1  Precision stavu 2  Recall stavu 0  Recall stavu 1  \
# ...

# %%
tab[3] = CL.validace_hromadna(CLF, train[3], test[3], delka_okna=[[4, 6], [8, 10], [12, 14, 16], range(5,17)],\
                           pocet_stavu=3, unsupervised = False, HMMmodified=False)
# Out:
# [########################################################################] 100%
# 1999.2556400299072

# %%
tab[3].to_csv(valid_path + 'Real_data_DTC_Hm_3.csv',index=False)

# %%
tab[3].sort_values(['Accuracy'], ascending=False).head(5)
# Out:
#        Kombinace rysů     délky úseku  Accuracy  Chyby  F míra stavu 0  \
# 3801  (1, 1, 1, 0, 1)  (6, 0, 16, 14)  0.870382   3140        0.904746
# 3428  (1, 1, 0, 1, 1)  (6, 0, 12, 16)  0.868471   3140        0.900499
# 3825  (1, 1, 1, 0, 1)  (0, 8, 14, 14)  0.867516   3140        0.902906
# 3706  (1, 1, 1, 0, 1)  (6, 8, 12, 15)  0.867516   3140        0.902842
# 3609  (1, 1, 1, 0, 1)  (4, 8, 14, 14)  0.866879   3140        0.903375
#
#       F míra stavu 1  F míra stavu 2  F míra průměrná  Precision stavu 0  \
# 3801        0.839707        0.838077         0.860843           0.883344
# 3428        0.840722        0.838114         0.859778           0.881433
# 3825        0.850746        0.825024         0.859559           0.877407
# 3706        0.841584        0.830558         0.858328           0.877892
# 3609        0.840364        0.828697         0.857479           0.879510
#
#       Precision stavu 1  Precision stavu 2  Recall stavu 0  Recall stavu 1  \
# ...

# %%
tab[4] = CL.validace_hromadna(CLF, train[4], test[4], delka_okna=[[4, 6], [8, 10], [12, 14, 16], range(5,17)],\
                           pocet_stavu=3, unsupervised = False, HMMmodified=False)
# Out:
# [########################################################################] 100%
# 2110.4638679027557

# %%
tab[4].to_csv(valid_path + 'Real_data_DTC_Hm_4.csv',index=False)

# %%
tab[4].sort_values(['Accuracy'], ascending=False).head(5)
# Out:
#        Kombinace rysů     délky úseku  Accuracy  Chyby  F míra stavu 0  \
# 3707  (1, 1, 1, 0, 1)  (6, 8, 12, 16)  0.868075   3646        0.913555
# 3599  (1, 1, 1, 0, 1)  (4, 8, 12, 16)  0.867800   3646        0.909637
# 3566  (1, 1, 1, 0, 0)  (4, 10, 16, 0)  0.867800   3646        0.910198
# 4107  (1, 1, 1, 1, 1)  (6, 10, 16, 5)  0.866978   3646        0.918025
# 3779  (1, 1, 1, 0, 1)  (6, 0, 12, 16)  0.866978   3646        0.910403
#
#       F míra stavu 1  F míra stavu 2  F míra průměrná  Precision stavu 0  \
# 3707        0.868522        0.743869         0.841982           0.888835
# 3599        0.879217        0.738862         0.842572           0.884185
# 3566        0.879002        0.743198         0.844133           0.896104
# 4107        0.853821        0.746827         0.839557           0.893607
# 3779        0.863736        0.751032         0.841724           0.880173
#
#       Precision stavu 1  Precision stavu 2  Recall stavu 0  Recall stavu 1  \
# ...

# %%
tab[5] = CL.validace_hromadna(CLF, train[5], test[5], delka_okna=[[4, 6], [8, 10], [12, 14, 16], range(5,17)],\
                           pocet_stavu=3, unsupervised = False, HMMmodified=False)
# Out:
# [########################################################################] 100%
# 2133.290677547455

# %%
tab[5].to_csv(valid_path + 'Real_data_DTC_Hm_5.csv',index=False)

# %%
tab[5].sort_values(['Accuracy'], ascending=False).head(5)
# Out:
#        Kombinace rysů      délky úseku  Accuracy  Chyby  F míra stavu 0  \
# 3760  (1, 1, 1, 0, 1)   (6, 10, 16, 9)  0.917371   3667        0.939843
# 3693  (1, 1, 1, 0, 1)   (4, 0, 16, 14)  0.916826   3667        0.940553
# 3759  (1, 1, 1, 0, 1)   (6, 10, 16, 8)  0.916280   3667        0.941804
# 4214  (1, 1, 1, 1, 1)  (0, 10, 14, 16)  0.915735   3667        0.937034
# 4173  (1, 1, 1, 1, 1)   (0, 8, 14, 11)  0.915735   3667        0.940309
#
#       F míra stavu 1  F míra stavu 2  F míra průměrná  Precision stavu 0  \
# 3760        0.929167        0.864522         0.911177           0.926974
# 3693        0.920969        0.864548         0.908690           0.923947
# 3759        0.919255        0.861314         0.907457           0.930797
# 4214        0.932773        0.864374         0.911394           0.931386
# 4173        0.922594        0.860226         0.907710           0.923913
#
#       Precision stavu 1  Precision stavu 2  Recall stavu 0  Recall stavu 1  \
# ...

# %%
tab[6] = CL.validace_hromadna(CLF, train[6], test[6], delka_okna=[[4, 6], [8, 10], [12, 14, 16], range(5,17)],\
                           pocet_stavu=3, unsupervised = False, HMMmodified=False)
# Out:
# [########################################################################] 100%
# 2099.0802121162415

# %%
tab[6].to_csv(valid_path + 'Real_data_DTC_Hm_6.csv',index=False)
tab[6].sort_values(['Accuracy'], ascending=False).head(5)
# Out:
#        Kombinace rysů      délky úseku  Accuracy  Chyby  F míra stavu 0  \
# 3599  (1, 1, 1, 0, 1)   (4, 8, 12, 16)  0.884303   3319        0.903921
# 3731  (1, 1, 1, 0, 1)   (6, 8, 16, 16)  0.884001   3319        0.900297
# 4094  (1, 1, 1, 1, 1)  (6, 10, 12, 16)  0.883097   3319        0.904875
# 4202  (1, 1, 1, 1, 1)  (0, 10, 12, 16)  0.882495   3319        0.899253
# 4058  (1, 1, 1, 1, 1)   (6, 8, 12, 16)  0.881892   3319        0.901703
#
#       F míra stavu 1  F míra stavu 2  F míra průměrná  Precision stavu 0  \
# 3599        0.863768        0.864893         0.877527           0.922419
# 3731        0.880640        0.857445         0.879461           0.910564
# 4094        0.865412        0.857294         0.875860           0.916867
# 4202        0.876177        0.857741         0.877723           0.916514
# 4058        0.869314        0.856243         0.875754           0.918442
#
#       Precision stavu 1  Precision stavu 2  Recall stavu 0  Recall stavu 1  \
# ...

# %%
tab[7] = CL.validace_hromadna(CLF, train[7], test[7], delka_okna=[[4, 6], [8, 10], [12, 14, 16], range(5,17)],\
                           pocet_stavu=3, unsupervised = False, HMMmodified=False)
# Out:
# [########################################################################] 100%
# 2023.6936428546906

# %%
tab[7].to_csv(valid_path + 'Real_data_DTC_Hm_7.csv',index=False)
tab[7].sort_values(['Accuracy'], ascending=False).head(5)
# Out:
#        Kombinace rysů     délky úseku  Accuracy  Chyby  F míra stavu 0  \
# 4146  (1, 1, 1, 1, 1)   (6, 0, 16, 8)  0.850901   3387        0.878725
# 3613  (1, 1, 1, 0, 1)   (4, 8, 16, 6)  0.850310   3387        0.877501
# 3692  (1, 1, 1, 0, 1)  (4, 0, 16, 13)  0.848834   3387        0.868043
# 3727  (1, 1, 1, 0, 1)  (6, 8, 16, 12)  0.848834   3387        0.876608
# 3723  (1, 1, 1, 0, 1)   (6, 8, 16, 8)  0.848834   3387        0.877132
#
#       F míra stavu 1  F míra stavu 2  F míra průměrná  Precision stavu 0  \
# 4146        0.838710        0.825674         0.847703           0.889201
# 3613        0.830975        0.830364         0.846280           0.899928
# 3692        0.847682        0.827991         0.847905           0.887616
# 3727        0.828762        0.828100         0.844490           0.889908
# 3723        0.836869        0.823204         0.845735           0.891720
#
#       Precision stavu 1  Precision stavu 2  Recall stavu 0  Recall stavu 1  \
# ...

# %%
tab[8] = CL.validace_hromadna(CLF, train[8], test[8], delka_okna=[[4, 6], [8, 10], [12, 14, 16], range(5,17)],\
                           pocet_stavu=3, unsupervised = False, HMMmodified=False)
# Out:
# [########################################################################] 100%
# 2056.7378828525543

# %%
tab[8].to_csv(valid_path + 'Real_data_DTC_Hm_8.csv',index=False)
tab[8].sort_values(['Accuracy'], ascending=False).head(5)
# Out:
#        Kombinace rysů      délky úseku  Accuracy  Chyby  F míra stavu 0  \
# 3914  (1, 1, 1, 1, 0)    (4, 8, 16, 0)  0.880803   3188        0.921745
# 4112  (1, 1, 1, 1, 1)  (6, 10, 16, 10)  0.877980   3188        0.919455
# 3760  (1, 1, 1, 0, 1)   (6, 10, 16, 9)  0.877039   3188        0.918204
# 4221  (1, 1, 1, 1, 1)  (0, 10, 16, 11)  0.876725   3188        0.915349
# 3721  (1, 1, 1, 0, 1)    (6, 8, 16, 6)  0.874216   3188        0.911447
#
#       F míra stavu 1  F míra stavu 2  F míra průměrná  Precision stavu 0  \
# 3914        0.870821        0.815545         0.869370           0.943038
# 4112        0.869102        0.811341         0.866633           0.942222
# 3760        0.872274        0.807609         0.866029           0.933709
# 4221        0.878856        0.806806         0.867004           0.938931
# 3721        0.886836        0.799564         0.865949           0.930101
#
#       Precision stavu 1  Precision stavu 2  Recall stavu 0  Recall stavu 1  \
# ...

# %%
tab[9] = CL.validace_hromadna(CLF, train[9], test[9], delka_okna=[[4, 6], [8, 10], [12, 14, 16], range(5,17)],\
                           pocet_stavu=3, unsupervised = False, HMMmodified=False)
# Out:
# [########################################################################] 100%
# 2086.728324174881

# %%
tab[9].to_csv(valid_path + 'Real_data_DTC_Hm_9.csv',index=False)
tab[9].sort_values(['Accuracy'], ascending=False).head(5)
# Out:
#        Kombinace rysů      délky úseku  Accuracy  Chyby  F míra stavu 0  \
# 4080  (1, 1, 1, 1, 1)   (6, 8, 16, 14)  0.857620   3596        0.893409
# 4225  (1, 1, 1, 1, 1)  (0, 10, 16, 15)  0.856785   3596        0.893927
# 3268  (1, 1, 0, 1, 1)   (4, 8, 16, 12)  0.855951   3596        0.893789
# 3682  (1, 1, 1, 0, 1)   (4, 0, 14, 15)  0.855673   3596        0.892711
# 4117  (1, 1, 1, 1, 1)  (6, 10, 16, 15)  0.855395   3596        0.891197
#
#       F míra stavu 1  F míra stavu 2  F míra průměrná  Precision stavu 0  \
# 4080        0.797267        0.827560         0.839412           0.917038
# 4225        0.808756        0.820160         0.840948           0.912900
# 3268        0.805556        0.818704         0.839350           0.909190
# 3682        0.817059        0.817286         0.842352           0.922686
# 4117        0.819333        0.818011         0.842847           0.922467
#
#       Precision stavu 1  Precision stavu 2  Recall stavu 0  Recall stavu 1  \
# ...
