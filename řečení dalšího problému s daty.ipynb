# %%
# %pylab --no-import-all notebook
import pandas as pd
import timeit
import os
import time
import copy
from random import shuffle
way = os.getcwd() + "/Data_npy/"
way1 = way + "Chosen ones/"
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dirr = os.listdir(way1)
dirr
# Out:
# ['No100.npy',
#  'No100_info.npy',
#  'No101.npy',
#  'No101_info.npy',
#  'No104.npy',
#  'No104_info.npy',
#  'No105.npy',
#  'No105_info.npy',
#  'No106.npy',
#  'No106_info.npy',
#  'No108.npy',
#  'No108_info.npy',
#  'No11.npy',
#  'No110.npy',
#  'No110_info.npy',
#  'No111.npy',
#  'No111_info.npy',
#  'No114.npy',
#  'No114_info.npy',
#  'No116.npy',
#  'No116_info.npy',
#  'No117.npy',
#  'No117_info.npy',
#  'No118.npy',
#  'No118_info.npy',
#  'No119.npy',
#  'No119_info.npy',
#  'No120.npy',
#  'No120_info.npy',
#  'No126.npy',
#  'No126_info.npy',
#  'No127.npy',
#  'No127_info.npy',
#  'No128.npy',
#  'No128_info.npy',
#  'No130.npy',
#  'No130_info.npy',
#  'No132.npy',
#  'No132_info.npy',
#  'No133.npy',
#  'No133_info.npy',
#  'No137.npy',
#  'No137_info.npy',
#  'No138.npy',
#  'No138_info.npy',
#  'No140.npy',
#  'No140_info.npy',
#  'No141.npy',
#  'No141_info.npy',
#  'No146.npy',
#  'No146_info.npy',
#  'No154.npy',
#  'No154_info.npy',
#  'No160.npy',
# ...

# %%
train_data = [np.load(way1 + "No100.npy"),np.load(way1 + "No101.npy"), np.load(way1 + "No108.npy"), np.load(way1 + "No324.npy") ]
test_data = [np.load(way1 + "No106.npy")]
print("done")
# Out:
# done

# %%
for train in train_data[1:]:
    print(train[1])
# Out:
# [ 0.32392348  0.35269222  0.40928647 ...,  0.21725904  0.22268265
#   0.1961934 ]
# [ 0.13307509  0.1332323   0.12662963 ...,  0.11531078  0.10925834
#   0.1056426 ]
# [ 0.16821069  0.15610581  0.15319749 ...,  0.1333109   0.12136322
#   0.12694405]

# %%
plt.figure("100")
plt.plot(train_data[0][0], train_data[0][1])
plt.scatter(train_data[0][0], train_data[0][1], c = train_data[0][2], cmap = plt.cm.plasma)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure("324")
plt.plot(train_data[3][0], train_data[3][1])
plt.scatter(train_data[3][0], train_data[3][1], c = train_data[3][2], cmap = plt.cm.plasma)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure("train data")
plt.plot(np.arange(len(train_data[0][1])), train_data[0][1])
plt.plot(np.arange(len(train_data[1][1]))+len(train_data[0][1]), train_data[1][1] - train_data[2][1].mean())
plt.plot(np.arange(len(train_data[2][1]))+len(train_data[0][1])+len(train_data[1][1]), train_data[2][1])
plt.plot(np.arange(len(train_data[3][1]))+len(train_data[0][1])+len(train_data[1][1])+len(train_data[2][1]), train_data[3][1])
#plt.plot(np.arange(len(train_data[2][1]))+len(train_data[0][1]), train_data[2][1])
#plt.plot(np.arange(len(train_data[3][1]))+len(train_data[0][1])+len(train_data[2][1]), train_data[3][1])
#plt.plot(train_data[2][0]+max(train_data[1][0]), train_data[2][1])
#plt.scatter(test_data[0][0], test_data[0][1], c = test_data[0][2], cmap = plt.cm.plasma)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sety = []
for data in dirr:
    if "info" in data:
        continue
    sety.append(data)
sety
# Out:
# ['No100.npy',
#  'No101.npy',
#  'No104.npy',
#  'No105.npy',
#  'No106.npy',
#  'No108.npy',
#  'No11.npy',
#  'No110.npy',
#  'No111.npy',
#  'No114.npy',
#  'No116.npy',
#  'No117.npy',
#  'No118.npy',
#  'No119.npy',
#  'No120.npy',
#  'No126.npy',
#  'No127.npy',
#  'No128.npy',
#  'No130.npy',
#  'No132.npy',
#  'No133.npy',
#  'No137.npy',
#  'No138.npy',
#  'No140.npy',
#  'No141.npy',
#  'No146.npy',
#  'No154.npy',
#  'No160.npy',
#  'No164.npy',
#  'No165.npy',
#  'No170.npy',
#  'No2.npy',
#  'No20.npy',
#  'No206.npy',
#  'No207.npy',
#  'No208.npy',
#  'No21.npy',
#  'No212.npy',
#  'No213.npy',
#  'No214.npy',
#  'No215.npy',
#  'No218.npy',
#  'No219.npy',
#  'No22.npy',
#  'No220.npy',
#  'No221.npy',
#  'No222.npy',
#  'No223.npy',
#  'No224.npy',
#  'No225.npy',
#  'No23.npy',
#  'No24.npy',
#  'No25.npy',
#  'No26.npy',
#  'No27.npy',
#  'No301.npy',
#  'No302.npy',
#  'No303.npy',
#  'No309.npy',
#  'No310.npy',
#  'No311.npy',
#  'No313.npy',
#  'No314.npy',
# ...

# %%
plt.figure("nákresy")
index = 0
posun = 0
tren = []
Y = [0]
for data in sety:
    X = np.load(way1 + data)[1]
    posun = max(Y)
    osa = np.arange(len(X)) + posun
    plt.plot(osa, X)
    plt.show()
    Y.append(posun+len(X))
    index+=1
    tren.append(data)
    #if index == 15:
    #    break
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
[np.load(way1+sety[7][:-4]+"_info.npy"),np.load(way1+sety[8][:-4]+"_info.npy")]
# Out:
# [array(['Record number: ', '15349'],
#        dtype='<U15'), array(['Record number: ', '15364'],
#        dtype='<U15')]

# %%
tren
# Out:
# ['No100.npy',
#  'No101.npy',
#  'No104.npy',
#  'No105.npy',
#  'No106.npy',
#  'No108.npy',
#  'No11.npy',
#  'No110.npy',
#  'No111.npy',
#  'No114.npy',
#  'No116.npy',
#  'No117.npy',
#  'No118.npy',
#  'No119.npy',
#  'No120.npy']

# %%
tes = copy.copy(tren[6])
del tren[0], tren[0], tren[4], tren[6]

# %%
tren
# Out:
# ['No104.npy',
#  'No105.npy',
#  'No106.npy',
#  'No108.npy',
#  'No110.npy',
#  'No111.npy',
#  'No116.npy',
#  'No117.npy',
#  'No118.npy',
#  'No119.npy',
#  'No120.npy']

# %%
tes
# Out:
# 'No11.npy'

# %%
plt.figure("nákresy I")
index = 0
posun = 0
Y = [0]
for d in tren:
    Z = np.load(way1 + d)[1]
    posun = max(Y)
    osa = np.arange(len(Z)) + posun
    plt.plot(osa, Z)
    Y.append(posun + len(Z))
    index+=1
    if index == 15:
        break

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#np.save(way + "seznam.npy", tren)

# %%
tren
# Out:
# ['No104.npy',
#  'No105.npy',
#  'No106.npy',
#  'No108.npy',
#  'No110.npy',
#  'No111.npy',
#  'No116.npy',
#  'No117.npy',
#  'No118.npy',
#  'No119.npy',
#  'No120.npy']

# %%
len(tren)
# Out:
# 11

# %%
del tren[10]
tren
# Out:
# ['No104.npy',
#  'No105.npy',
#  'No106.npy',
#  'No108.npy',
#  'No110.npy',
#  'No111.npy',
#  'No116.npy',
#  'No117.npy',
#  'No118.npy',
#  'No119.npy']

# %%
#np.save(way + "seznam.npy", tren)

# %%
test_data = [np.load(way1 + "No106.npy")]

# %%
plt.figure("testy")
plt.plot(test_data[0][0], test_data[0][1])
plt.scatter(test_data[0][0], test_data[0][1], c = test_data[0][2], cmap = plt.cm.plasma)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.show()
