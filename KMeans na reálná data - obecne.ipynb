# %%
# %pylab --no-import-all notebook
import warnings
import pandas as pd
import Classification as CL
from K_Means import K_means
import os
import time
from copy import copy
way = os.getcwd() + "/Data_npy/"
way1 = way + "Chosen ones/"
valid_path = os.getcwd() + "/Validační tabulky/"
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
trlist = np.load(way1 + "new_list.npy").tolist()

# %%
tmp = [np.load(way1 + d)[1] for d in trlist]
plt.figure("Vybraná reálná data")
posun = 0
for i in tmp:
    plt.plot(np.arange(len(i))+ posun, i, '-', lw=0.5)
    posun = posun +len(i) 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
norma = [CL.normalization(np.load(way1 + d)[1] , delka_useku = 20, training_set = True) for d in trlist]
plt.figure("Vybraná reálná data po normalizaci")
posun = 0
for i in norma:
    plt.plot(np.arange(len(i))+ posun, i, '-', lw=0.5)
    posun = posun +len(i)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
train_data = []
for data in trlist:
    train_data.append(np.load(way1 + data))

# %%
import sklearn.cluster as sk

# %%
km = sk.KMeans(3)

# %%
val = CL.validace_new(km, train_data[:-1], [train_data[-1]],\
                      delka_okna =[[4,6], [8,10], [12,14,16], range(5,17)], unsupervised = True)
# Out:
# [########################################################################] 100%
# 3653.501452922821

# %%
val.to_csv(valid_path + 'Real_data_KM_1_Obecne.csv',index=False)

# %%
tr2 = copy(train_data[:-2]) + copy(train_data[-1:])
len(tr2)
# Out:
# 9

# %%
val2 = CL.validace_new(km, tr2, [train_data[-2]],\
                      delka_okna =[[4,6], [8,10], [12,14,16], range(5,17)], unsupervised = True)
# Out:
# [########################################################################] 100%
# 3717.114842891693

# %%
val2.to_csv(valid_path + 'Real_data_KM_2_Obecne.csv',index=False)

# %%
tr3 = copy(train_data[:-3]) + copy(train_data[-2:])
len(tr3)
# Out:
# 9

# %%
val3 = CL.validace_new(km, tr3, [train_data[-3]],\
                      delka_okna =[[4,6], [8,10], [12,14,16], range(5,17)], unsupervised = True)
# Out:
# [########################################################################] 100%
# 3179.200959920883

# %%
val3.to_csv(valid_path + 'Real_data_KM_3_Obecne.csv',index=False)

# %%
tr4 = copy(train_data[:-4]) + copy(train_data[-3:])
len(tr4)
# Out:
# 9

# %%
val4 = CL.validace_new(km, tr4, [train_data[-4]],\
                      delka_okna =[[4,6], [8,10], [12,14,16], range(5,17)], unsupervised = True)
# Out:
# [########################################################################] 100%
# 3948.442591905594

# %%
val4.to_csv(valid_path + 'Real_data_KM_4_Obecne.csv',index=False)

# %%
tr5 = copy(train_data[:-5]) + copy(train_data[-4:])
len(tr5)
# Out:
# 9

# %%
val5 = CL.validace_new(km, tr5, [train_data[-5]],\
                      delka_okna =[[4,6], [8,10], [12,14,16], range(5,17)], unsupervised = True)
# Out:
# [########################################################################] 100%
# 3411.4982340335846

# %%
val5.to_csv(valid_path + 'Real_data_KM_5_Obecne.csv',index=False)

# %%
tr6 = copy(train_data[:-6]) + copy(train_data[-5:])
len(tr6)
# Out:
# 9

# %%
val6 = CL.validace_new(km, tr6, [train_data[-6]],\
                      delka_okna =[[4,6], [8,10], [12,14,16], range(5,17)], unsupervised = True)
# Out:
# [########################################################################] 100%
# 2502.24689912796

# %%
val6.to_csv(valid_path + 'Real_data_KM_6_Obecne.csv',index=False)

# %%
tr7 = copy(train_data[:-7]) + copy(train_data[-6:])
len(tr7)
# Out:
# 9

# %%
val7 = CL.validace_new(km, tr7, [train_data[-7]],\
                      delka_okna =[[4,6], [8,10], [12,14,16], range(5,17)], unsupervised = True)
# Out:
# [########################################################################] 100%
# 3421.73650097847

# %%
val7.to_csv(valid_path + 'Real_data_KM_7_Obecne.csv',index=False)

# %%
tr8 = copy(train_data[:-8]) + copy(train_data[-7:])
len(tr8)
# Out:
# 9

# %%
val8 = CL.validace_new(km, tr8, [train_data[-8]],\
                      delka_okna =[[4,6], [8,10], [12,14,16], range(5,17)], unsupervised = True)
# Out:
# [########################################################################] 100%
# 2946.1654567718506

# %%
val8.to_csv(valid_path + 'Real_data_KM_8_Obecne.csv',index=False)

# %%
tr9 = copy(train_data[:-9]) + copy(train_data[-8:])
len(tr9)
# Out:
# 9

# %%
tr10 = copy(train_data[:-10]) + copy(train_data[-9:])
len(tr10)
# Out:
# 9

# %%
val9 = CL.validace_new(km, tr9, [train_data[-9]],\
                      delka_okna =[[4,6], [8,10], [12,14,16], range(5,17)], unsupervised = True)
# Out:
# [########################################################################] 100%
# 3149.853264808655

# %%
val9.to_csv(valid_path + 'Real_data_KM_9_Obecne.csv',index=False)

# %%
val10 = CL.validace_new(km, tr10, [train_data[-10]],\
                      delka_okna =[[4,6], [8,10], [12,14,16], range(5,17)], unsupervised = True)
# Out:
# [########################################################################] 100%
# 3341.2682740688324

# %%
val10.to_csv(valid_path + 'Real_data_KM_10_Obecne.csv',index=False)
