# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
X = np.load("No1.npy")

# %%
plt.plot(X[0],X[1])

# %%
X = np.load("No2.npy")
plt.plot(X[0],X[1])

# %%
X = np.load("No3.npy")
plt.plot(X[0],X[1])

# %%
X = np.load("No4.npy")
plt.plot(X[0],X[1])

# %%
X = np.load("No5.npy")
plt.plot(X[0],X[1])

# %%
X = np.load("No6.npy")
plt.plot(X[0],X[1])

# %%
X = np.load("No7.npy")
plt.plot(X[0],X[1])

# %%
np.load("No7_res.npy").tolist()
# Out:
# ['Record number: ',
#  '15546',
#  't_hmode: ',
#  '1065.99',
#  '1175.81',
#  '1190.1100000000001',
#  '1195.71',
#  '1201.44']

# %%
X = np.load("No8.npy")
plt.plot(X[0],X[1])

# %%
X = np.load("No9.npy")
plt.plot(X[0],X[1])

# %%
X = np.load("No10.npy")
plt.plot(X[0],X[1])

# %%
# Out:
# 6000

# %%
X = np.load("No11.npy")
plt.plot(X[0],X[1])
